# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**
# Image caption uses an encoder-decoder architecture, where encoder extrancts features from the given images, and decoder generates captions based on the the features from the encoder. Encoder uses a CNN network because is good at processing images, and Decoder uses LSTM. Embed size is chosen as 256, and hidden size is 512 referring to the paper. Vocabulary count threshold is chosen to be 5 in order to igore infrequently shown words.
# 1. __CNN Encoder__:
#     * Has ResNet50 architecture pretrained on imagenet to extract the features from the images.
#     * Added one fully-connected (linear) layer to transform features extracted from the images into embeddings.
# 2. __LSTM Decoder__:
#     * Has 1 embedding layer to transform the input image features and captions into embeddings.
#     * Has LSTM layer with possibility to extend the number of LSTM layers and adding the dropout layers between them.
#     * Has 1 fully-connected linear layer to transform the output into the vocabulary keys.
#
# Chosen variable values:
# * __batch_size__ - I chose the batch size of 128 images, because the dataset is relatively big, so we don't need a small batch for accurate predictions. On the other hand the batch size of 128 is large, so the model is training relatively fast. Fortunately, the GPU allows us to use this batch size without exceeding the available amount of memory.
# *  __vocab_threshold__ - I chose the threshold of 5, because this seemed to be a reasonable medium size vocabulary choice.
# * __embed_size__ - 256 as a recommended standard choice for the size of the embedding.
# * __hidden_size__ - 512 seemed to be a reasonable hidden size to be chosen not to overfit the model.
# * __num_epochs__ - I started with 3 epochs. When evaluating the performance of the model I came to a conclusion, that this number of epochs is sufficient.
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** I left the given transform_train as it is because the trained model gives a good result. RandomCrop with 224 is necessary to ensure the size of images to be the same size. RandomHorizontalFlip with 0.5 probability auguments training image data so that the model can be trained on more dataset. Normalize the images with the same average and standard deviation value as the training dataset (ImageNet) to make them same as the pre-trained model's distribution.
#
#
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**
#
# My trainable parameters:
#
# 1. __All decoder parameters__ because my decoder has a relatively small number of parameters, that is why training them all will not result in overfitting.
# 2. __Just embedding parameters for the encoder__ because the encoder is already pretrainied on image net and updating the parameters for our dataset could possibly lead to overfitting. On the other hand training all ResNet50 parameters is also computationally intensive and will lead to slower training.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/mnt/ssd2/kcheng/gpu205/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32           # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 12            # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=1.05s)
# creating index...
#   0%|          | 614/414113 [00:00<01:07, 6133.09it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [00:52<00:00, 7880.55it/s]
# /mnt/ssd2/kcheng/miniconda3/envs/cv-nd/lib/python3.6/site-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.4 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
# Move models to GPU if CUDA is available. 
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1,2,3,4,5,6,7
print('Num of GPUs available: ', torch.cuda.device_count())
device = torch.device("cuda:6" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.linear.parameters()) + list(encoder.bn.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.001)

# Set the total number of training steps per epoch.
# total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
total_step = len(data_loader)
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1,2,3,4,5,6,7
# Num of GPUs available:  7

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import os
import torch.utils.data as data
import numpy as np
import requests
import time
from torch.nn.utils.rnn import pack_padded_sequence

# Open the training log file.
# f = open(log_file, 'w')

# old_time = time.time()
# response = requests.request("GET", 
#                             "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
#                             headers={"Metadata-Flavor":"Google"})

os.makedirs('./models-attention', exist_ok=True)

for epoch in range(num_epochs):
    for i, (images, captions, lengths) in enumerate(data_loader):
        
        # Set mini-batch dataset
        images = images.to(device)
        captions = captions.to(device)
        targets = pack_padded_sequence(captions, lengths, batch_first=True)[0]


        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features, cnn_features = encoder(images)
        outputs = decoder(features, cnn_features, captions, lengths)
        
        # Calculate the batch loss.
        loss = criterion(outputs, targets)
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
        
        # Print log info
        if i % 1000 == 0:
            print('Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f'
                  %(epoch, num_epochs, i, total_step, 
                    loss.item(), np.exp(loss.item()))) 

        # Save the models
        if (i+1) % total_step == 0:
            torch.save(decoder.state_dict(), os.path.join('./models-attention', 'decoder-%d-%d.pkl' %(epoch+1, i+1)))
            torch.save(encoder.state_dict(), os.path.join('./models-attention', 'encoder-%d-%d.pkl' %(epoch+1, i+1)))
        
# Close the training log file.
# f.close()
# Out:
# /mnt/ssd2/kcheng/miniconda3/envs/cv-nd/lib/python3.6/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /mnt/ssd2/kcheng/gpu205/Image-Captioning-Project/model.py:107: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   attention_weights = self.softmax(attention_weights)
# Epoch [0/12], Step [0/12941], Loss: 9.0837, Perplexity: 8810.8760
# Epoch [0/12], Step [1000/12941], Loss: 3.1444, Perplexity: 23.2057
# Epoch [0/12], Step [2000/12941], Loss: 2.3911, Perplexity: 10.9257
# Epoch [0/12], Step [3000/12941], Loss: 2.0555, Perplexity: 7.8109
# Epoch [0/12], Step [4000/12941], Loss: 2.3712, Perplexity: 10.7099
# Epoch [0/12], Step [5000/12941], Loss: 2.3001, Perplexity: 9.9751
# Epoch [0/12], Step [6000/12941], Loss: 2.3154, Perplexity: 10.1285
# Epoch [0/12], Step [7000/12941], Loss: 2.2774, Perplexity: 9.7515
# Epoch [0/12], Step [8000/12941], Loss: 2.2991, Perplexity: 9.9651
# Epoch [0/12], Step [9000/12941], Loss: 2.1282, Perplexity: 8.4001
# Epoch [0/12], Step [10000/12941], Loss: 2.1303, Perplexity: 8.4170
# Epoch [0/12], Step [11000/12941], Loss: 2.2037, Perplexity: 9.0588
# Epoch [0/12], Step [12000/12941], Loss: 2.2502, Perplexity: 9.4895
# Epoch [1/12], Step [0/12941], Loss: 1.9807, Perplexity: 7.2475
# Epoch [1/12], Step [1000/12941], Loss: 2.1746, Perplexity: 8.7989
# Epoch [1/12], Step [2000/12941], Loss: 1.9381, Perplexity: 6.9459
# Epoch [1/12], Step [3000/12941], Loss: 2.1161, Perplexity: 8.2987
# Epoch [1/12], Step [4000/12941], Loss: 2.0296, Perplexity: 7.6109
# Epoch [1/12], Step [5000/12941], Loss: 2.2296, Perplexity: 9.2964
# Epoch [1/12], Step [6000/12941], Loss: 2.2038, Perplexity: 9.0598
# Epoch [1/12], Step [7000/12941], Loss: 1.9279, Perplexity: 6.8749
# Epoch [1/12], Step [8000/12941], Loss: 2.0251, Perplexity: 7.5766
# Epoch [1/12], Step [9000/12941], Loss: 1.8647, Perplexity: 6.4542
# Epoch [1/12], Step [10000/12941], Loss: 2.2224, Perplexity: 9.2297
# Epoch [1/12], Step [11000/12941], Loss: 2.3434, Perplexity: 10.4164
# Epoch [1/12], Step [12000/12941], Loss: 2.0867, Perplexity: 8.0581
# Epoch [2/12], Step [0/12941], Loss: 1.8414, Perplexity: 6.3057
# Epoch [2/12], Step [1000/12941], Loss: 2.1849, Perplexity: 8.8902
# Epoch [2/12], Step [2000/12941], Loss: 2.1062, Perplexity: 8.2172
# Epoch [2/12], Step [3000/12941], Loss: 2.2146, Perplexity: 9.1579
# Epoch [2/12], Step [4000/12941], Loss: 2.0505, Perplexity: 7.7719
# Epoch [2/12], Step [5000/12941], Loss: 1.7741, Perplexity: 5.8948
# Epoch [2/12], Step [6000/12941], Loss: 1.9626, Perplexity: 7.1180
# Epoch [2/12], Step [7000/12941], Loss: 1.9390, Perplexity: 6.9520
# Epoch [2/12], Step [8000/12941], Loss: 2.1519, Perplexity: 8.6011
# Epoch [2/12], Step [9000/12941], Loss: 1.9524, Perplexity: 7.0459
# Epoch [2/12], Step [10000/12941], Loss: 2.1584, Perplexity: 8.6573
# Epoch [2/12], Step [11000/12941], Loss: 1.9585, Perplexity: 7.0890
# Epoch [2/12], Step [12000/12941], Loss: 1.9144, Perplexity: 6.7826
# Epoch [3/12], Step [0/12941], Loss: 2.0210, Perplexity: 7.5455
# Epoch [3/12], Step [1000/12941], Loss: 1.8448, Perplexity: 6.3265
# Epoch [3/12], Step [2000/12941], Loss: 2.0605, Perplexity: 7.8495
# Epoch [3/12], Step [3000/12941], Loss: 1.9157, Perplexity: 6.7916
# Epoch [3/12], Step [4000/12941], Loss: 2.2114, Perplexity: 9.1286
# Epoch [3/12], Step [5000/12941], Loss: 2.1490, Perplexity: 8.5762
# Epoch [3/12], Step [6000/12941], Loss: 1.8278, Perplexity: 6.2204
# Epoch [3/12], Step [7000/12941], Loss: 1.9245, Perplexity: 6.8519
# Epoch [3/12], Step [8000/12941], Loss: 1.9324, Perplexity: 6.9062
# Epoch [3/12], Step [9000/12941], Loss: 1.9387, Perplexity: 6.9499
# Epoch [3/12], Step [10000/12941], Loss: 2.2329, Perplexity: 9.3273
# Epoch [3/12], Step [11000/12941], Loss: 1.9569, Perplexity: 7.0774
# Epoch [3/12], Step [12000/12941], Loss: 1.9978, Perplexity: 7.3727
# Epoch [4/12], Step [0/12941], Loss: 1.9858, Perplexity: 7.2846
# Epoch [4/12], Step [1000/12941], Loss: 1.9456, Perplexity: 6.9978
# Epoch [4/12], Step [2000/12941], Loss: 1.7495, Perplexity: 5.7519
# Epoch [4/12], Step [3000/12941], Loss: 1.6372, Perplexity: 5.1407
# Epoch [4/12], Step [4000/12941], Loss: 1.6979, Perplexity: 5.4626
# Epoch [4/12], Step [5000/12941], Loss: 1.8309, Perplexity: 6.2396
# Epoch [4/12], Step [6000/12941], Loss: 1.8901, Perplexity: 6.6198
# Epoch [4/12], Step [7000/12941], Loss: 2.0128, Perplexity: 7.4844
# Epoch [4/12], Step [8000/12941], Loss: 2.0820, Perplexity: 8.0206
# Epoch [4/12], Step [9000/12941], Loss: 2.0035, Perplexity: 7.4152
# Epoch [4/12], Step [10000/12941], Loss: 2.0225, Perplexity: 7.5574
# Epoch [4/12], Step [11000/12941], Loss: 1.8089, Perplexity: 6.1036
# Epoch [4/12], Step [12000/12941], Loss: 1.7393, Perplexity: 5.6935
# Epoch [5/12], Step [0/12941], Loss: 1.7136, Perplexity: 5.5487
# Epoch [5/12], Step [1000/12941], Loss: 1.7249, Perplexity: 5.6119
# Epoch [5/12], Step [2000/12941], Loss: 1.9722, Perplexity: 7.1866
# Epoch [5/12], Step [3000/12941], Loss: 1.7560, Perplexity: 5.7894
# Epoch [5/12], Step [4000/12941], Loss: 2.1299, Perplexity: 8.4143
# Epoch [5/12], Step [5000/12941], Loss: 2.0457, Perplexity: 7.7347
# Epoch [5/12], Step [6000/12941], Loss: 1.9267, Perplexity: 6.8669
# Epoch [5/12], Step [7000/12941], Loss: 1.9442, Perplexity: 6.9879
# Epoch [5/12], Step [8000/12941], Loss: 1.9147, Perplexity: 6.7851
# Epoch [5/12], Step [9000/12941], Loss: 1.9236, Perplexity: 6.8457
# Epoch [5/12], Step [10000/12941], Loss: 1.8192, Perplexity: 6.1667
# Epoch [5/12], Step [11000/12941], Loss: 2.0080, Perplexity: 7.4483
# Epoch [5/12], Step [12000/12941], Loss: 1.9579, Perplexity: 7.0847
# Epoch [6/12], Step [0/12941], Loss: 1.8597, Perplexity: 6.4215
# Epoch [6/12], Step [1000/12941], Loss: 1.8307, Perplexity: 6.2382
# Epoch [6/12], Step [2000/12941], Loss: 1.8970, Perplexity: 6.6657
# Epoch [6/12], Step [3000/12941], Loss: 1.8142, Perplexity: 6.1361
# Epoch [6/12], Step [4000/12941], Loss: 1.8585, Perplexity: 6.4139
# Epoch [6/12], Step [5000/12941], Loss: 1.8264, Perplexity: 6.2118
# Epoch [6/12], Step [6000/12941], Loss: 1.8178, Perplexity: 6.1584
# Epoch [6/12], Step [7000/12941], Loss: 1.7621, Perplexity: 5.8246
# Epoch [6/12], Step [8000/12941], Loss: 1.7717, Perplexity: 5.8806
# Epoch [6/12], Step [9000/12941], Loss: 1.8341, Perplexity: 6.2597
# Epoch [6/12], Step [10000/12941], Loss: 1.9901, Perplexity: 7.3164
# Epoch [6/12], Step [11000/12941], Loss: 1.8616, Perplexity: 6.4342
# Epoch [6/12], Step [12000/12941], Loss: 1.8417, Perplexity: 6.3075
# Epoch [7/12], Step [0/12941], Loss: 1.7767, Perplexity: 5.9101
# Epoch [7/12], Step [1000/12941], Loss: 1.6593, Perplexity: 5.2556
# Epoch [7/12], Step [2000/12941], Loss: 1.8200, Perplexity: 6.1716
# Epoch [7/12], Step [3000/12941], Loss: 1.9067, Perplexity: 6.7307
# Epoch [7/12], Step [4000/12941], Loss: 1.6972, Perplexity: 5.4587
# Epoch [7/12], Step [5000/12941], Loss: 1.6561, Perplexity: 5.2386
# Epoch [7/12], Step [6000/12941], Loss: 1.8357, Perplexity: 6.2693
# Epoch [7/12], Step [7000/12941], Loss: 1.7285, Perplexity: 5.6321
# Epoch [7/12], Step [8000/12941], Loss: 1.6994, Perplexity: 5.4706
# Epoch [7/12], Step [9000/12941], Loss: 1.8233, Perplexity: 6.1922
# Epoch [7/12], Step [10000/12941], Loss: 1.6198, Perplexity: 5.0523
# Epoch [7/12], Step [11000/12941], Loss: 1.6473, Perplexity: 5.1928
# Epoch [7/12], Step [12000/12941], Loss: 1.8700, Perplexity: 6.4884
# Epoch [8/12], Step [0/12941], Loss: 1.7767, Perplexity: 5.9100
# Epoch [8/12], Step [1000/12941], Loss: 1.8836, Perplexity: 6.5771
# Epoch [8/12], Step [2000/12941], Loss: 1.7980, Perplexity: 6.0373
# Epoch [8/12], Step [3000/12941], Loss: 1.6945, Perplexity: 5.4438
# Epoch [8/12], Step [4000/12941], Loss: 1.7423, Perplexity: 5.7104
# Epoch [8/12], Step [5000/12941], Loss: 1.7855, Perplexity: 5.9623
# Epoch [8/12], Step [6000/12941], Loss: 1.6726, Perplexity: 5.3262
# Epoch [8/12], Step [7000/12941], Loss: 1.7612, Perplexity: 5.8192
# Epoch [8/12], Step [8000/12941], Loss: 1.8722, Perplexity: 6.5023
# Epoch [8/12], Step [9000/12941], Loss: 2.0325, Perplexity: 7.6328
# Epoch [8/12], Step [10000/12941], Loss: 1.6814, Perplexity: 5.3731
# Epoch [8/12], Step [11000/12941], Loss: 1.9934, Perplexity: 7.3402
# Epoch [8/12], Step [12000/12941], Loss: 1.9443, Perplexity: 6.9889
# Epoch [9/12], Step [0/12941], Loss: 1.7498, Perplexity: 5.7534
# Epoch [9/12], Step [1000/12941], Loss: 1.8629, Perplexity: 6.4422
# Epoch [9/12], Step [2000/12941], Loss: 1.7372, Perplexity: 5.6812
# Epoch [9/12], Step [3000/12941], Loss: 1.8103, Perplexity: 6.1122
# Epoch [9/12], Step [4000/12941], Loss: 1.8069, Perplexity: 6.0917
# Epoch [9/12], Step [5000/12941], Loss: 2.0355, Perplexity: 7.6561
# Epoch [9/12], Step [6000/12941], Loss: 1.6483, Perplexity: 5.1983
# Epoch [9/12], Step [7000/12941], Loss: 1.7342, Perplexity: 5.6644
# Epoch [9/12], Step [8000/12941], Loss: 1.8464, Perplexity: 6.3369
# Epoch [9/12], Step [9000/12941], Loss: 1.9614, Perplexity: 7.1094
# Epoch [9/12], Step [10000/12941], Loss: 1.9185, Perplexity: 6.8105
# Epoch [9/12], Step [11000/12941], Loss: 1.7463, Perplexity: 5.7332
# Epoch [9/12], Step [12000/12941], Loss: 1.7731, Perplexity: 5.8888
# Epoch [10/12], Step [0/12941], Loss: 1.7234, Perplexity: 5.6034
# Epoch [10/12], Step [1000/12941], Loss: 1.7077, Perplexity: 5.5161
# Epoch [10/12], Step [2000/12941], Loss: 1.6029, Perplexity: 4.9672
# Epoch [10/12], Step [3000/12941], Loss: 1.6844, Perplexity: 5.3891
# Epoch [10/12], Step [4000/12941], Loss: 1.7611, Perplexity: 5.8191
# Epoch [10/12], Step [5000/12941], Loss: 1.6509, Perplexity: 5.2119
# Epoch [10/12], Step [6000/12941], Loss: 1.6538, Perplexity: 5.2269
# Epoch [10/12], Step [7000/12941], Loss: 1.7776, Perplexity: 5.9155
# Epoch [10/12], Step [8000/12941], Loss: 2.0420, Perplexity: 7.7063
# Epoch [10/12], Step [9000/12941], Loss: 1.8598, Perplexity: 6.4223
# Epoch [10/12], Step [10000/12941], Loss: 1.8203, Perplexity: 6.1734
# Epoch [10/12], Step [11000/12941], Loss: 1.9147, Perplexity: 6.7852
# Epoch [10/12], Step [12000/12941], Loss: 1.9375, Perplexity: 6.9415
# Epoch [11/12], Step [0/12941], Loss: 1.7166, Perplexity: 5.5653
# Epoch [11/12], Step [1000/12941], Loss: 1.8515, Perplexity: 6.3694
# Epoch [11/12], Step [2000/12941], Loss: 1.8020, Perplexity: 6.0619
# Epoch [11/12], Step [3000/12941], Loss: 1.5707, Perplexity: 4.8102
# Epoch [11/12], Step [4000/12941], Loss: 1.8239, Perplexity: 6.1962
# Epoch [11/12], Step [5000/12941], Loss: 1.6207, Perplexity: 5.0567
# Epoch [11/12], Step [6000/12941], Loss: 1.8477, Perplexity: 6.3454
# Epoch [11/12], Step [7000/12941], Loss: 2.0336, Perplexity: 7.6416
# Epoch [11/12], Step [8000/12941], Loss: 2.0196, Perplexity: 7.5356
# Epoch [11/12], Step [9000/12941], Loss: 1.8930, Perplexity: 6.6393
# Epoch [11/12], Step [10000/12941], Loss: 1.9194, Perplexity: 6.8170
# Epoch [11/12], Step [11000/12941], Loss: 1.6017, Perplexity: 4.9613
# Epoch [11/12], Step [12000/12941], Loss: 1.7798, Perplexity: 5.9286

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
from data_loader_val import get_loader_val

# Setup transforms
transform_val = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
#     transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# batch_size = 1

# Create the data loader
data_loader_val = get_loader_val(transform=transform_val,
                                mode='val')

# %%
# Watch for any changes in model.py, and re-load it automatically.
% load_ext autoreload
% autoreload 2

# load the model
from model import EncoderCNN, DecoderRNN
import os
import matplotlib.pyplot as plt
import numpy as np

# Specify the saved models to load.
encoder_file = 'encoder-3.pkl'
decoder_file = 'decoder-3.pkl'

# Select appropriate values for the Python variables below.
embed_size = 256
hidden_size = 512

# The size of the vocabulary.
vocab_size = len(data_loader_val.dataset.vocab)

# Initialize the encoder and decoder, and set each to inference mode.
encoder = EncoderCNN(embed_size)
encoder.eval()
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)
decoder.eval()

# Load the trained weights.
encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))

# Move models to GPU if CUDA is available.
encoder.to(device)
decoder.to(device)

# %%
import nltk

# (Optional) TODO: Validate your model.
def clean_sentence(output):
    sentence = ''
    for x in output:
        sentence += ' ' + data_loader_val.dataset.vocab.idx2word[x]
        sentence = sentence.strip()
    return sentence

def get_prediction():
    orig_image, image = next(iter(data_loader_val))
    plt.imshow(np.squeeze(orig_image))
    plt.title('Sample Image')
    plt.show()
    image = image.to(device)
    features = encoder(image).unsqueeze(1)
    output = decoder.sample(features)    
    sentence = clean_sentence(output)
    print('Predicted caption: {}'.format(sentence))

# %%
get_prediction()

# %%
get_prediction()
